# %% [markdown]
# # Setup

# %%
# DATA LINKS

henry_imdb = "/content/drive/MyDrive/Courses/Sophomore Spring Courses/CS226R/IMDB Dataset Processed.csv"
henry_imdb_debiased = "/content/drive/MyDrive/Courses/Sophomore Spring Courses/CS226R/IMDB Dataset Processed (Debiased).csv"

joseph_imdb = "/content/drive/MyDrive/CS226R Final Project/IMDB Dataset Processed (1000).csv"
joseph_imdb_debiased = "/content/drive/MyDrive/CS226R Final Project/IMDB Dataset Processed (Debiased) (1000).csv"

# joseph_imdb_custom_debiased = '/content/drive/MyDrive/CS226R Final Project/IMDB Dataset Processed (Debiased, Custom, 1000).csv'
joseph_imdb_custom_debiased = '/content/drive/MyDrive/CS226R Final Project/IMDB Dataset Processed (Debiased, Custom, 1000, New).csv'

# %%
# Fairness Libraries
# https://fairlearn.org/v0.10/api_reference/generated/fairlearn.reductions.EqualizedOdds.html
# https://aif360.readthedocs.io/en/stable/modules/explainers.html

# %%
# !pip install aif360
# !pip install fairlearn
# !pip install datasets
# Out:
# Requirement already satisfied: aif360 in /usr/local/lib/python3.10/dist-packages (0.6.1)
# Requirement already satisfied: numpy>=1.16 in /usr/local/lib/python3.10/dist-packages (from aif360) (1.25.2)
# Requirement already satisfied: scipy>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from aif360) (1.11.4)
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.10/dist-packages (from aif360) (2.0.3)
# Requirement already satisfied: scikit-learn>=1.0 in /usr/local/lib/python3.10/dist-packages (from aif360) (1.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from aif360) (3.7.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24.0->aif360) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24.0->aif360) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24.0->aif360) (2024.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0->aif360) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0->aif360) (3.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->aif360) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->aif360) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->aif360) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->aif360) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->aif360) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->aif360) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->aif360) (3.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=0.24.0->aif360) (1.16.0)
# Requirement already satisfied: fairlearn in /usr/local/lib/python3.10/dist-packages (0.10.0)
# Requirement already satisfied: numpy>=1.24.4 in /usr/local/lib/python3.10/dist-packages (from fairlearn) (1.25.2)
# Requirement already satisfied: pandas>=2.0.3 in /usr/local/lib/python3.10/dist-packages (from fairlearn) (2.0.3)
# Requirement already satisfied: scikit-learn>=1.2.1 in /usr/local/lib/python3.10/dist-packages (from fairlearn) (1.2.2)
# Requirement already satisfied: scipy>=1.9.3 in /usr/local/lib/python3.10/dist-packages (from fairlearn) (1.11.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.0.3->fairlearn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.0.3->fairlearn) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.0.3->fairlearn) (2024.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.2.1->fairlearn) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.2.1->fairlearn) (3.4.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=2.0.3->fairlearn) (1.16.0)
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (2.19.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.13.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.25.2)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.0.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.2)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec[http]<=2024.3.1,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.5)
# Requirement already satisfied: huggingface-hub>=0.21.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.22.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.2->datasets) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2024.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)

# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score
from transformers import BertTokenizer, BertForSequenceClassification, Trainer, TrainingArguments
from datasets import load_dataset
from fairlearn.preprocessing import CorrelationRemover
from fairlearn.reductions import DemographicParity, EqualizedOdds
from aif360.datasets import BinaryLabelDataset
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install fairlearn
# Out:
# ERROR: Operation cancelled by user

# %%
# Load datasets

# imdb = pd.read_csv(henry_imdb)
# imdb_debiased = pd.read_csv(henry_imdb_debiased)
imdb = pd.read_csv(joseph_imdb)
imdb_debiased = pd.read_csv(joseph_imdb_debiased)

imdb_custom_debiased = pd.read_csv(joseph_imdb_custom_debiased)

# %% [markdown]
# # Fairness Metrics

# %%
# https://fairware.cs.umass.edu/papers/Verma.pdf

from sklearn.metrics import confusion_matrix

def evaluate_metrics_for_specific_value(y_true, y_pred, protected_column = None, specific_value = None):
    if specific_value:
        # Use boolean array to directly index y_true and y_pred
        mask = protected_column == specific_value
        cm = confusion_matrix(y_true[mask], y_pred[mask])
    else:
        cm = confusion_matrix(y_true, y_pred)
    # Ensure the confusion matrix has dimensions [2, 2]
    if cm.shape != (2, 2):
        cm = np.pad(cm, ((2-cm.shape[0], 0), (2-cm.shape[1], 0)), mode='constant')

    # Extract TP, FP, FN, TN for the specific value
    TP = cm[1, 1] if len(cm) > 1 else 0
    FP = cm[0, 1] if len(cm) > 1 else 0
    FN = cm[1, 0] if len(cm) > 1 else 0
    TN = cm[0, 0] if len(cm) > 1 else 0

    # Compute metrics
    PPV = TP / (TP + FP) if TP + FP > 0 else 0  # Positive Predictive Value (Precision)
    FDR = FP / (TP + FP) if TP + FP > 0 else 0  # False Discovery Rate
    FOR = FN / (TN + FN) if TN + FN > 0 else 0  # False Omission Rate
    NPV = TN / (TN + FN) if TN + FN > 0 else 0  # Negative Predictive Value
    TPR = TP / (TP + FN) if TP + FN > 0 else 0  # True Positive Rate (Recall/Sensitivity)
    FPR = FP / (FP + TN) if FP + TN > 0 else 0  # False Positive Rate
    FNR = FN / (TP + FN) if TP + FN > 0 else 0  # False Negative Rate
    TNR = TN / (FP + TN) if FP + TN > 0 else 0  # True Negative Rate

    if specific_value:
        metrics_dict = {
            f'True Positive Rate ({specific_value})': TPR,
            f'False Positive Rate ({specific_value})': FPR,
            f'False Negative Rate ({specific_value})': FNR,
            f'True Negative Rate ({specific_value})': TNR,
            f'Positive Predictive Value (Precision) ({specific_value})': PPV,
            f'False Discovery Rate ({specific_value})': FDR,
            f'False Omission Rate ({specific_value})': FOR,
            f'Negative Predictive Value ({specific_value})': NPV
        }
    else:
        metrics_dict = {
            'True Positive Rate': TPR,
            'False Positive Rate': FPR,
            'False Negative Rate': FNR,
            'True Negative Rate': TNR,
            'Positive Predictive Value (Precision)': PPV,
            'False Discovery Rate': FDR,
            'False Omission Rate': FOR,
            'Negative Predictive Value': NPV
        }

    return metrics_dict

# %% [markdown]
# # Establish classifier baseline

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import AdaBoostClassifier
from sklearn.mixture import GaussianMixture
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %%
import pickle

df = imdb
# Check the unique values of the sentiment column
print("Unique values in 'sentiment':", df['sentiment'].unique())
label_mapping = {'negative': 0, 'positive': 1}
df['sentiment'] = df['sentiment'].map(label_mapping)
print("Unique values in 'sentiment':", df['sentiment'].unique())
class ClassifierComparison:
    def __init__(self, df, feature_columns, target_column, protected_column, test_size=0.2, random_state=42):
        self.df = df
        self.feature_columns = feature_columns
        self.target_column = target_column
        self.protected_column = protected_column
        self.test_size = test_size
        self.random_state = random_state

        self.classifiers = {
          "Logistic Regression": LogisticRegression(),
          "Decision Tree": DecisionTreeClassifier(),
          "Support Vector Machine": SVC(),
          "AdaBoost": AdaBoostClassifier(),
          "Linear SVC": LinearSVC(),
          "Gaussian Mixture": GaussianMixture(),
          "Linear Discriminant Analysis": LinearDiscriminantAnalysis()
      }


        self.X = df[feature_columns]
        self.y = df[target_column]

        indices = np.arange(self.X.shape[0])

        self.X_train, self.X_test, self.y_train, self.y_test, self.idx_train, self.idx_test = train_test_split(
    self.X, self.y, indices, test_size=self.test_size, random_state=self.random_state)

        self.results = {}

    def train_and_evaluate(self):
        for name, clf in self.classifiers.items():
            clf.fit(self.X_train, self.y_train)
            y_pred = clf.predict(self.X_test)

            accuracy = accuracy_score(self.y_test, y_pred)

            # Get protected column values only for the test indices
            protected_test_values = self.df[self.protected_column].iloc[self.idx_test]

            # Fairness metrics
            dp_diff = demographic_parity_difference(self.y_test, y_pred, sensitive_features=protected_test_values)
            eo_diff = equalized_odds_difference(self.y_test, y_pred, sensitive_features=protected_test_values)

            male_metrics = evaluate_metrics_for_specific_value(self.y_test, y_pred, protected_test_values, 'male')
            female_metrics = evaluate_metrics_for_specific_value(self.y_test, y_pred, protected_test_values, 'female')
            general_metrics = evaluate_metrics_for_specific_value(self.y_test, y_pred, protected_test_values, None)

            self.results[name] = {
                'Accuracy': accuracy,
                'Demographic Parity Difference': dp_diff,
                'Equalized Odds Difference': eo_diff,
                **general_metrics,
                **female_metrics,
                **male_metrics,
            }

    def display_results(self):
        for name, metrics_dict in self.results.items():
            print(f"{name}: Accuracy - {metrics_dict['Accuracy']:.4f}, Demographic Parity Difference - {metrics_dict['Demographic Parity Difference']:.4f}, Equalized Odds Difference - {metrics_dict['Equalized Odds Difference']:.4f}")
            for metric_name, metric_value in metrics_dict.items():
                if metric_name not in ['Accuracy', 'Demographic Parity Difference', 'Equalized Odds Difference']:
                    print(f"    {metric_name}: {metric_value:.4f}")
            print()

    def save_results(self, filename):
        with open(filename, 'wb') as file:
            pickle.dump(self.results, file)
# Out:
# Unique values in 'sentiment': ['positive' 'negative']
# Unique values in 'sentiment': [1 0]

# %% [markdown]
# # Regular

# %%
from sklearn.preprocessing import LabelEncoder
df = imdb
feature_columns = [col for col in df.columns if col.startswith('sentence_embedding_')]
target_column = 'sentiment'
protected_column = 'gender'
test_size = 0.2
random_state = 42

# Instantiate the ClassifierComparison object
cc = ClassifierComparison(df, feature_columns, target_column, protected_column, test_size, random_state)

# Encode the sentiment column to numeric values
label_encoder = LabelEncoder()
df['sentiment'] = label_encoder.fit_transform(df['sentiment'])
print("Unique values in 'sentiment' after encoding:", df['sentiment'].unique())
cc = ClassifierComparison(df, feature_columns, target_column, protected_column, test_size, random_state)

# Train and evaluate classifiers
cc.train_and_evaluate()

# Display results
cc.display_results()
# Out:
# Unique values in 'sentiment' after encoding: [1 0]
# Logistic Regression: Accuracy - 0.7650, Demographic Parity Difference - 0.2880, Equalized Odds Difference - 0.3652
#     True Positive Rate: 0.9174
#     False Positive Rate: 0.4684
#     False Negative Rate: 0.0826
#     True Negative Rate: 0.5316
#     Positive Predictive Value (Precision): 0.7500
#     False Discovery Rate: 0.2500
#     False Omission Rate: 0.1923
#     Negative Predictive Value: 0.8077
#     True Positive Rate (female): 0.9310
#     False Positive Rate (female): 0.6579
#     False Negative Rate (female): 0.0690
#     True Negative Rate (female): 0.3421
#     Positive Predictive Value (Precision) (female): 0.7642
#     False Discovery Rate (female): 0.2358
#     False Omission Rate (female): 0.3158
#     Negative Predictive Value (female): 0.6842
#     True Positive Rate (male): 0.8824
#     False Positive Rate (male): 0.2927
#     False Negative Rate (male): 0.1176
#     True Negative Rate (male): 0.7073
#     Positive Predictive Value (Precision) (male): 0.7143
#     False Discovery Rate (male): 0.2857
#     False Omission Rate (male): 0.1212
#     Negative Predictive Value (male): 0.8788
#
# Decision Tree: Accuracy - 0.6850, Demographic Parity Difference - 0.2347, Equalized Odds Difference - 0.2049
#     True Positive Rate: 0.7355
#     False Positive Rate: 0.3924
#     False Negative Rate: 0.2645
#     True Negative Rate: 0.6076
#     Positive Predictive Value (Precision): 0.7417
#     False Discovery Rate: 0.2583
#     False Omission Rate: 0.4000
#     Negative Predictive Value: 0.6000
#     True Positive Rate (female): 0.7931
#     False Positive Rate (female): 0.4474
#     False Negative Rate (female): 0.2069
#     True Negative Rate (female): 0.5526
#     Positive Predictive Value (Precision) (female): 0.8023
#     False Discovery Rate (female): 0.1977
#     False Omission Rate (female): 0.4615
#     Negative Predictive Value (female): 0.5385
#     True Positive Rate (male): 0.5882
#     False Positive Rate (male): 0.3415
#     False Negative Rate (male): 0.4118
#     True Negative Rate (male): 0.6585
#     Positive Predictive Value (Precision) (male): 0.5882
#     False Discovery Rate (male): 0.4118
#     False Omission Rate (male): 0.3415
#     Negative Predictive Value (male): 0.6585
#
# Random Forest: Accuracy - 0.7200, Demographic Parity Difference - 0.3867, Equalized Odds Difference - 0.4159
#     True Positive Rate: 0.8430
#     False Positive Rate: 0.4684
#     False Negative Rate: 0.1570
#     True Negative Rate: 0.5316
#     Positive Predictive Value (Precision): 0.7338
#     False Discovery Rate: 0.2662
#     False Omission Rate: 0.3115
#     Negative Predictive Value: 0.6885
#     True Positive Rate (female): 0.9080
#     False Positive Rate (female): 0.6842
#     False Negative Rate (female): 0.0920
#     True Negative Rate (female): 0.3158
#     Positive Predictive Value (Precision) (female): 0.7524
#     False Discovery Rate (female): 0.2476
#     False Omission Rate (female): 0.4000
#     Negative Predictive Value (female): 0.6000
#     True Positive Rate (male): 0.6765
#     False Positive Rate (male): 0.2683
#     False Negative Rate (male): 0.3235
#     True Negative Rate (male): 0.7317
#     Positive Predictive Value (Precision) (male): 0.6765
#     False Discovery Rate (male): 0.3235
#     False Omission Rate (male): 0.2683
#     Negative Predictive Value (male): 0.7317
#
# Support Vector Machine: Accuracy - 0.7400, Demographic Parity Difference - 0.3120, Equalized Odds Difference - 0.3614
#     True Positive Rate: 0.8430
#     False Positive Rate: 0.4177
#     False Negative Rate: 0.1570
#     True Negative Rate: 0.5823
#     Positive Predictive Value (Precision): 0.7556
#     False Discovery Rate: 0.2444
#     False Omission Rate: 0.2923
#     Negative Predictive Value: 0.7077
#     True Positive Rate (female): 0.8736
#     False Positive Rate (female): 0.6053
#     False Negative Rate (female): 0.1264
#     True Negative Rate (female): 0.3947
#     Positive Predictive Value (Precision) (female): 0.7677
#     False Discovery Rate (female): 0.2323
#     False Omission Rate (female): 0.4231
#     Negative Predictive Value (female): 0.5769
#     True Positive Rate (male): 0.7647
#     False Positive Rate (male): 0.2439
#     False Negative Rate (male): 0.2353
#     True Negative Rate (male): 0.7561
#     Positive Predictive Value (Precision) (male): 0.7222
#     False Discovery Rate (male): 0.2778
#     False Omission Rate (male): 0.2051
#     Negative Predictive Value (male): 0.7949
#
# K-Nearest Neighbors: Accuracy - 0.6900, Demographic Parity Difference - 0.3013, Equalized Odds Difference - 0.2882
#     True Positive Rate: 0.7851
#     False Positive Rate: 0.4557
#     False Negative Rate: 0.2149
#     True Negative Rate: 0.5443
#     Positive Predictive Value (Precision): 0.7252
#     False Discovery Rate: 0.2748
#     False Omission Rate: 0.3768
#     Negative Predictive Value: 0.6232
#     True Positive Rate (female): 0.8391
#     False Positive Rate (female): 0.6053
#     False Negative Rate (female): 0.1609
#     True Negative Rate (female): 0.3947
#     Positive Predictive Value (Precision) (female): 0.7604
#     False Discovery Rate (female): 0.2396
#     False Omission Rate (female): 0.4828
#     Negative Predictive Value (female): 0.5172
#     True Positive Rate (male): 0.6471
#     False Positive Rate (male): 0.3171
#     False Negative Rate (male): 0.3529
#     True Negative Rate (male): 0.6829
#     Positive Predictive Value (Precision) (male): 0.6286
#     False Discovery Rate (male): 0.3714
#     False Omission Rate (male): 0.3000
#     Negative Predictive Value (male): 0.7000
#
# Extra Trees: Accuracy - 0.7750, Demographic Parity Difference - 0.2933, Equalized Odds Difference - 0.3126
#     True Positive Rate: 0.9174
#     False Positive Rate: 0.4430
#     False Negative Rate: 0.0826
#     True Negative Rate: 0.5570
#     Positive Predictive Value (Precision): 0.7603
#     False Discovery Rate: 0.2397
#     False Omission Rate: 0.1852
#     Negative Predictive Value: 0.8148
#     True Positive Rate (female): 0.9425
#     False Positive Rate (female): 0.6053
#     False Negative Rate (female): 0.0575
#     True Negative Rate (female): 0.3947
#     Positive Predictive Value (Precision) (female): 0.7810
#     False Discovery Rate (female): 0.2190
#     False Omission Rate (female): 0.2500
#     Negative Predictive Value (female): 0.7500
#     True Positive Rate (male): 0.8529
#     False Positive Rate (male): 0.2927
#     False Negative Rate (male): 0.1471
#     True Negative Rate (male): 0.7073
#     Positive Predictive Value (Precision) (male): 0.7073
#     False Discovery Rate (male): 0.2927
#     False Omission Rate (male): 0.1471
#     Negative Predictive Value (male): 0.8529
#
# Gradient Boosting: Accuracy - 0.7300, Demographic Parity Difference - 0.2427, Equalized Odds Difference - 0.2580
#     True Positive Rate: 0.8099
#     False Positive Rate: 0.3924
#     False Negative Rate: 0.1901
#     True Negative Rate: 0.6076
#     Positive Predictive Value (Precision): 0.7597
#     False Discovery Rate: 0.2403
#     False Omission Rate: 0.3239
#     Negative Predictive Value: 0.6761
#     True Positive Rate (female): 0.8276
#     False Positive Rate (female): 0.5263
#     False Negative Rate (female): 0.1724
#     True Negative Rate (female): 0.4737
#     Positive Predictive Value (Precision) (female): 0.7826
#     False Discovery Rate (female): 0.2174
#     False Omission Rate (female): 0.4545
#     Negative Predictive Value (female): 0.5455
#     True Positive Rate (male): 0.7647
#     False Positive Rate (male): 0.2683
#     False Negative Rate (male): 0.2353
#     True Negative Rate (male): 0.7317
#     Positive Predictive Value (Precision) (male): 0.7027
#     False Discovery Rate (male): 0.2973
#     False Omission Rate (male): 0.2105
#     Negative Predictive Value (male): 0.7895
#
# AdaBoost: Accuracy - 0.7300, Demographic Parity Difference - 0.1947, Equalized Odds Difference - 0.2336
#     True Positive Rate: 0.8182
#     False Positive Rate: 0.4051
#     False Negative Rate: 0.1818
#     True Negative Rate: 0.5949
#     Positive Predictive Value (Precision): 0.7557
#     False Discovery Rate: 0.2443
#     False Omission Rate: 0.3188
#     Negative Predictive Value: 0.6812
#     True Positive Rate (female): 0.8161
#     False Positive Rate (female): 0.5263
#     False Negative Rate (female): 0.1839
#     True Negative Rate (female): 0.4737
#     Positive Predictive Value (Precision) (female): 0.7802
#     False Discovery Rate (female): 0.2198
#     False Omission Rate (female): 0.4706
#     Negative Predictive Value (female): 0.5294
#     True Positive Rate (male): 0.8235
#     False Positive Rate (male): 0.2927
#     False Negative Rate (male): 0.1765
#     True Negative Rate (male): 0.7073
#     Positive Predictive Value (Precision) (male): 0.7000
#     False Discovery Rate (male): 0.3000
#     False Omission Rate (male): 0.1714
#     Negative Predictive Value (male): 0.8286
#
# Linear SVC: Accuracy - 0.7650, Demographic Parity Difference - 0.2720, Equalized Odds Difference - 0.2805
#     True Positive Rate: 0.8430
#     False Positive Rate: 0.3544
#     False Negative Rate: 0.1570
#     True Negative Rate: 0.6456
#     Positive Predictive Value (Precision): 0.7846
#     False Discovery Rate: 0.2154
#     False Omission Rate: 0.2714
#     Negative Predictive Value: 0.7286
#     True Positive Rate (female): 0.8621
#     False Positive Rate (female): 0.5000
#     False Negative Rate (female): 0.1379
#     True Negative Rate (female): 0.5000
#     Positive Predictive Value (Precision) (female): 0.7979
#     False Discovery Rate (female): 0.2021
#     False Omission Rate (female): 0.3871
#     Negative Predictive Value (female): 0.6129
#     True Positive Rate (male): 0.7941
#     False Positive Rate (male): 0.2195
#     False Negative Rate (male): 0.2059
#     True Negative Rate (male): 0.7805
#     Positive Predictive Value (Precision) (male): 0.7500
#     False Discovery Rate (male): 0.2500
#     False Omission Rate (male): 0.1795
#     Negative Predictive Value (male): 0.8205
#
# Gaussian Mixture: Accuracy - 0.3950, Demographic Parity Difference - 0.0000, Equalized Odds Difference - 0.0000
#     True Positive Rate: 0.0000
#     False Positive Rate: 0.0000
#     False Negative Rate: 1.0000
#     True Negative Rate: 1.0000
#     Positive Predictive Value (Precision): 0.0000
#     False Discovery Rate: 0.0000
#     False Omission Rate: 0.6050
#     Negative Predictive Value: 0.3950
#     True Positive Rate (female): 0.0000
#     False Positive Rate (female): 0.0000
#     False Negative Rate (female): 1.0000
#     True Negative Rate (female): 1.0000
#     Positive Predictive Value (Precision) (female): 0.0000
#     False Discovery Rate (female): 0.0000
#     False Omission Rate (female): 0.6960
#     Negative Predictive Value (female): 0.3040
#     True Positive Rate (male): 0.0000
#     False Positive Rate (male): 0.0000
#     False Negative Rate (male): 1.0000
#     True Negative Rate (male): 1.0000
#     Positive Predictive Value (Precision) (male): 0.0000
#     False Discovery Rate (male): 0.0000
#     False Omission Rate (male): 0.4533
#     Negative Predictive Value (male): 0.5467
#
# Linear Discriminant Analysis: Accuracy - 0.7200, Demographic Parity Difference - 0.1680, Equalized Odds Difference - 0.0757
#     True Positive Rate: 0.7521
#     False Positive Rate: 0.3291
#     False Negative Rate: 0.2479
#     True Negative Rate: 0.6709
#     Positive Predictive Value (Precision): 0.7778
#     False Discovery Rate: 0.2222
#     False Omission Rate: 0.3614
#     Negative Predictive Value: 0.6386
#     True Positive Rate (female): 0.7701
#     False Positive Rate (female): 0.3684
#     False Negative Rate (female): 0.2299
#     True Negative Rate (female): 0.6316
#     Positive Predictive Value (Precision) (female): 0.8272
#     False Discovery Rate (female): 0.1728
#     False Omission Rate (female): 0.4545
#     Negative Predictive Value (female): 0.5455
#     True Positive Rate (male): 0.7059
#     False Positive Rate (male): 0.2927
#     False Negative Rate (male): 0.2941
#     True Negative Rate (male): 0.7073
#     Positive Predictive Value (Precision) (male): 0.6667
#     False Discovery Rate (male): 0.3333
#     False Omission Rate (male): 0.2564
#     Negative Predictive Value (male): 0.7436
#
# MLP Classifier: Accuracy - 0.7650, Demographic Parity Difference - 0.2453, Equalized Odds Difference - 0.1508
#     True Positive Rate: 0.8182
#     False Positive Rate: 0.3165
#     False Negative Rate: 0.1818
#     True Negative Rate: 0.6835
#     Positive Predictive Value (Precision): 0.7984
#     False Discovery Rate: 0.2016
#     False Omission Rate: 0.2895
#     Negative Predictive Value: 0.7105
#     True Positive Rate (female): 0.8506
#     False Positive Rate (female): 0.3947
#     False Negative Rate (female): 0.1494
#     True Negative Rate (female): 0.6053
#     Positive Predictive Value (Precision) (female): 0.8315
#     False Discovery Rate (female): 0.1685
#     False Omission Rate (female): 0.3611
#     Negative Predictive Value (female): 0.6389
#     True Positive Rate (male): 0.7353
#     False Positive Rate (male): 0.2439
#     False Negative Rate (male): 0.2647
#     True Negative Rate (male): 0.7561
#     Positive Predictive Value (Precision) (male): 0.7143
#     False Discovery Rate (male): 0.2857
#     False Omission Rate (male): 0.2250
#     Negative Predictive Value (male): 0.7750
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %% [markdown]
# # Debiased

# %%
from sklearn.preprocessing import LabelEncoder
df = imdb_debiased
feature_columns = [col for col in df.columns if col.startswith('sentence_embedding_')]
target_column = 'sentiment'
protected_column = 'gender'
test_size = 0.2
random_state = 42

# Instantiate the ClassifierComparison object
cc = ClassifierComparison(df, feature_columns, target_column, protected_column, test_size, random_state)

# Encode the sentiment column to numeric values
label_encoder = LabelEncoder()
df['sentiment'] = label_encoder.fit_transform(df['sentiment'])
print("Unique values in 'sentiment' after encoding:", df['sentiment'].unique())
cc = ClassifierComparison(df, feature_columns, target_column, protected_column, test_size, random_state)

# Train and evaluate classifiers
cc.train_and_evaluate()

# Display results
cc.display_results()
# Out:
# Unique values in 'sentiment' after encoding: [1 0]
# Logistic Regression: Accuracy - 0.6050, Demographic Parity Difference - 0.0267, Equalized Odds Difference - 0.0294
#     True Positive Rate: 0.9917
#     False Positive Rate: 0.9873
#     False Negative Rate: 0.0083
#     True Negative Rate: 0.0127
#     Positive Predictive Value (Precision): 0.6061
#     False Discovery Rate: 0.3939
#     False Omission Rate: 0.5000
#     Negative Predictive Value: 0.5000
#     True Positive Rate (female): 1.0000
#     False Positive Rate (female): 1.0000
#     False Negative Rate (female): 0.0000
#     True Negative Rate (female): 0.0000
#     Positive Predictive Value (Precision) (female): 0.6960
#     False Discovery Rate (female): 0.3040
#     False Omission Rate (female): 0.0000
#     Negative Predictive Value (female): 0.0000
#     True Positive Rate (male): 0.9706
#     False Positive Rate (male): 0.9756
#     False Negative Rate (male): 0.0294
#     True Negative Rate (male): 0.0244
#     Positive Predictive Value (Precision) (male): 0.4521
#     False Discovery Rate (male): 0.5479
#     False Omission Rate (male): 0.5000
#     Negative Predictive Value (male): 0.5000
#
# Decision Tree: Accuracy - 0.7100, Demographic Parity Difference - 0.1307, Equalized Odds Difference - 0.1231
#     True Positive Rate: 0.7355
#     False Positive Rate: 0.3291
#     False Negative Rate: 0.2645
#     True Negative Rate: 0.6709
#     Positive Predictive Value (Precision): 0.7739
#     False Discovery Rate: 0.2261
#     False Omission Rate: 0.3765
#     Negative Predictive Value: 0.6235
#     True Positive Rate (female): 0.7701
#     False Positive Rate (female): 0.2895
#     False Negative Rate (female): 0.2299
#     True Negative Rate (female): 0.7105
#     Positive Predictive Value (Precision) (female): 0.8590
#     False Discovery Rate (female): 0.1410
#     False Omission Rate (female): 0.4255
#     Negative Predictive Value (female): 0.5745
#     True Positive Rate (male): 0.6471
#     False Positive Rate (male): 0.3659
#     False Negative Rate (male): 0.3529
#     True Negative Rate (male): 0.6341
#     Positive Predictive Value (Precision) (male): 0.5946
#     False Discovery Rate (male): 0.4054
#     False Omission Rate (male): 0.3158
#     Negative Predictive Value (male): 0.6842
#
# Random Forest: Accuracy - 0.7600, Demographic Parity Difference - 0.3920, Equalized Odds Difference - 0.4872
#     True Positive Rate: 0.8678
#     False Positive Rate: 0.4051
#     False Negative Rate: 0.1322
#     True Negative Rate: 0.5949
#     Positive Predictive Value (Precision): 0.7664
#     False Discovery Rate: 0.2336
#     False Omission Rate: 0.2540
#     Negative Predictive Value: 0.7460
#     True Positive Rate (female): 0.9080
#     False Positive Rate (female): 0.6579
#     False Negative Rate (female): 0.0920
#     True Negative Rate (female): 0.3421
#     Positive Predictive Value (Precision) (female): 0.7596
#     False Discovery Rate (female): 0.2404
#     False Omission Rate (female): 0.3810
#     Negative Predictive Value (female): 0.6190
#     True Positive Rate (male): 0.7647
#     False Positive Rate (male): 0.1707
#     False Negative Rate (male): 0.2353
#     True Negative Rate (male): 0.8293
#     Positive Predictive Value (Precision) (male): 0.7879
#     False Discovery Rate (male): 0.2121
#     False Omission Rate (male): 0.1905
#     Negative Predictive Value (male): 0.8095
#
# Support Vector Machine: Accuracy - 0.7550, Demographic Parity Difference - 0.3360, Equalized Odds Difference - 0.3614
#     True Positive Rate: 0.8678
#     False Positive Rate: 0.4177
#     False Negative Rate: 0.1322
#     True Negative Rate: 0.5823
#     Positive Predictive Value (Precision): 0.7609
#     False Discovery Rate: 0.2391
#     False Omission Rate: 0.2581
#     Negative Predictive Value: 0.7419
#     True Positive Rate (female): 0.9080
#     False Positive Rate (female): 0.6053
#     False Negative Rate (female): 0.0920
#     True Negative Rate (female): 0.3947
#     Positive Predictive Value (Precision) (female): 0.7745
#     False Discovery Rate (female): 0.2255
#     False Omission Rate (female): 0.3478
#     Negative Predictive Value (female): 0.6522
#     True Positive Rate (male): 0.7647
#     False Positive Rate (male): 0.2439
#     False Negative Rate (male): 0.2353
#     True Negative Rate (male): 0.7561
#     Positive Predictive Value (Precision) (male): 0.7222
#     False Discovery Rate (male): 0.2778
#     False Omission Rate (male): 0.2051
#     Negative Predictive Value (male): 0.7949
#
# K-Nearest Neighbors: Accuracy - 0.6750, Demographic Parity Difference - 0.3467, Equalized Odds Difference - 0.3671
#     True Positive Rate: 0.7851
#     False Positive Rate: 0.4937
#     False Negative Rate: 0.2149
#     True Negative Rate: 0.5063
#     Positive Predictive Value (Precision): 0.7090
#     False Discovery Rate: 0.2910
#     False Omission Rate: 0.3939
#     Negative Predictive Value: 0.6061
#     True Positive Rate (female): 0.8506
#     False Positive Rate (female): 0.6842
#     False Negative Rate (female): 0.1494
#     True Negative Rate (female): 0.3158
#     Positive Predictive Value (Precision) (female): 0.7400
#     False Discovery Rate (female): 0.2600
#     False Omission Rate (female): 0.5200
#     Negative Predictive Value (female): 0.4800
#     True Positive Rate (male): 0.6176
#     False Positive Rate (male): 0.3171
#     False Negative Rate (male): 0.3824
#     True Negative Rate (male): 0.6829
#     Positive Predictive Value (Precision) (male): 0.6176
#     False Discovery Rate (male): 0.3824
#     False Omission Rate (male): 0.3171
#     Negative Predictive Value (male): 0.6829
#
# Extra Trees: Accuracy - 0.7200, Demographic Parity Difference - 0.3493, Equalized Odds Difference - 0.3389
#     True Positive Rate: 0.8347
#     False Positive Rate: 0.4557
#     False Negative Rate: 0.1653
#     True Negative Rate: 0.5443
#     Positive Predictive Value (Precision): 0.7372
#     False Discovery Rate: 0.2628
#     False Omission Rate: 0.3175
#     Negative Predictive Value: 0.6825
#     True Positive Rate (female): 0.8966
#     False Positive Rate (female): 0.6316
#     False Negative Rate (female): 0.1034
#     True Negative Rate (female): 0.3684
#     Positive Predictive Value (Precision) (female): 0.7647
#     False Discovery Rate (female): 0.2353
#     False Omission Rate (female): 0.3913
#     Negative Predictive Value (female): 0.6087
#     True Positive Rate (male): 0.6765
#     False Positive Rate (male): 0.2927
#     False Negative Rate (male): 0.3235
#     True Negative Rate (male): 0.7073
#     Positive Predictive Value (Precision) (male): 0.6571
#     False Discovery Rate (male): 0.3429
#     False Omission Rate (male): 0.2750
#     Negative Predictive Value (male): 0.7250
#
# Gradient Boosting: Accuracy - 0.7450, Demographic Parity Difference - 0.2933, Equalized Odds Difference - 0.3331
#     True Positive Rate: 0.8264
#     False Positive Rate: 0.3797
#     False Negative Rate: 0.1736
#     True Negative Rate: 0.6203
#     Positive Predictive Value (Precision): 0.7692
#     False Discovery Rate: 0.2308
#     False Omission Rate: 0.3000
#     Negative Predictive Value: 0.7000
#     True Positive Rate (female): 0.8506
#     False Positive Rate (female): 0.5526
#     False Negative Rate (female): 0.1494
#     True Negative Rate (female): 0.4474
#     Positive Predictive Value (Precision) (female): 0.7789
#     False Discovery Rate (female): 0.2211
#     False Omission Rate (female): 0.4333
#     Negative Predictive Value (female): 0.5667
#     True Positive Rate (male): 0.7647
#     False Positive Rate (male): 0.2195
#     False Negative Rate (male): 0.2353
#     True Negative Rate (male): 0.7805
#     Positive Predictive Value (Precision) (male): 0.7429
#     False Discovery Rate (male): 0.2571
#     False Omission Rate (male): 0.2000
#     Negative Predictive Value (male): 0.8000
#
# AdaBoost: Accuracy - 0.7500, Demographic Parity Difference - 0.3013, Equalized Odds Difference - 0.2824
#     True Positive Rate: 0.8347
#     False Positive Rate: 0.3797
#     False Negative Rate: 0.1653
#     True Negative Rate: 0.6203
#     Positive Predictive Value (Precision): 0.7710
#     False Discovery Rate: 0.2290
#     False Omission Rate: 0.2899
#     Negative Predictive Value: 0.7101
#     True Positive Rate (female): 0.8736
#     False Positive Rate (female): 0.5263
#     False Negative Rate (female): 0.1264
#     True Negative Rate (female): 0.4737
#     Positive Predictive Value (Precision) (female): 0.7917
#     False Discovery Rate (female): 0.2083
#     False Omission Rate (female): 0.3793
#     Negative Predictive Value (female): 0.6207
#     True Positive Rate (male): 0.7353
#     False Positive Rate (male): 0.2439
#     False Negative Rate (male): 0.2647
#     True Negative Rate (male): 0.7561
#     Positive Predictive Value (Precision) (male): 0.7143
#     False Discovery Rate (male): 0.2857
#     False Omission Rate (male): 0.2250
#     Negative Predictive Value (male): 0.7750
#
# Linear SVC: Accuracy - 0.7500, Demographic Parity Difference - 0.3333, Equalized Odds Difference - 0.3896
#     True Positive Rate: 0.8843
#     False Positive Rate: 0.4557
#     False Negative Rate: 0.1157
#     True Negative Rate: 0.5443
#     Positive Predictive Value (Precision): 0.7483
#     False Discovery Rate: 0.2517
#     False Omission Rate: 0.2456
#     Negative Predictive Value: 0.7544
#     True Positive Rate (female): 0.9195
#     False Positive Rate (female): 0.6579
#     False Negative Rate (female): 0.0805
#     True Negative Rate (female): 0.3421
#     Positive Predictive Value (Precision) (female): 0.7619
#     False Discovery Rate (female): 0.2381
#     False Omission Rate (female): 0.3500
#     Negative Predictive Value (female): 0.6500
#     True Positive Rate (male): 0.7941
#     False Positive Rate (male): 0.2683
#     False Negative Rate (male): 0.2059
#     True Negative Rate (male): 0.7317
#     Positive Predictive Value (Precision) (male): 0.7105
#     False Discovery Rate (male): 0.2895
#     False Omission Rate (male): 0.1892
#     Negative Predictive Value (male): 0.8108
#
# Gaussian Mixture: Accuracy - 0.3950, Demographic Parity Difference - 0.0000, Equalized Odds Difference - 0.0000
#     True Positive Rate: 0.0000
#     False Positive Rate: 0.0000
#     False Negative Rate: 1.0000
#     True Negative Rate: 1.0000
#     Positive Predictive Value (Precision): 0.0000
#     False Discovery Rate: 0.0000
#     False Omission Rate: 0.6050
#     Negative Predictive Value: 0.3950
#     True Positive Rate (female): 0.0000
#     False Positive Rate (female): 0.0000
#     False Negative Rate (female): 1.0000
#     True Negative Rate (female): 1.0000
#     Positive Predictive Value (Precision) (female): 0.0000
#     False Discovery Rate (female): 0.0000
#     False Omission Rate (female): 0.6960
#     Negative Predictive Value (female): 0.3040
#     True Positive Rate (male): 0.0000
#     False Positive Rate (male): 0.0000
#     False Negative Rate (male): 1.0000
#     True Negative Rate (male): 1.0000
#     Positive Predictive Value (Precision) (male): 0.0000
#     False Discovery Rate (male): 0.0000
#     False Omission Rate (male): 0.4533
#     Negative Predictive Value (male): 0.5467
#
# Linear Discriminant Analysis: Accuracy - 0.7550, Demographic Parity Difference - 0.1333, Equalized Odds Difference - 0.0284
#     True Positive Rate: 0.7851
#     False Positive Rate: 0.2911
#     False Negative Rate: 0.2149
#     True Negative Rate: 0.7089
#     Positive Predictive Value (Precision): 0.8051
#     False Discovery Rate: 0.1949
#     False Omission Rate: 0.3171
#     Negative Predictive Value: 0.6829
#     True Positive Rate (female): 0.7931
#     False Positive Rate (female): 0.2895
#     False Negative Rate (female): 0.2069
#     True Negative Rate (female): 0.7105
#     Positive Predictive Value (Precision) (female): 0.8625
#     False Discovery Rate (female): 0.1375
#     False Omission Rate (female): 0.4000
#     Negative Predictive Value (female): 0.6000
#     True Positive Rate (male): 0.7647
#     False Positive Rate (male): 0.2927
#     False Negative Rate (male): 0.2353
#     True Negative Rate (male): 0.7073
#     Positive Predictive Value (Precision) (male): 0.6842
#     False Discovery Rate (male): 0.3158
#     False Omission Rate (male): 0.2162
#     Negative Predictive Value (male): 0.7838
#
# MLP Classifier: Accuracy - 0.7650, Demographic Parity Difference - 0.3147, Equalized Odds Difference - 0.2805
#     True Positive Rate: 0.8430
#     False Positive Rate: 0.3544
#     False Negative Rate: 0.1570
#     True Negative Rate: 0.6456
#     Positive Predictive Value (Precision): 0.7846
#     False Discovery Rate: 0.2154
#     False Omission Rate: 0.2714
#     Negative Predictive Value: 0.7286
#     True Positive Rate (female): 0.8851
#     False Positive Rate (female): 0.5000
#     False Negative Rate (female): 0.1149
#     True Negative Rate (female): 0.5000
#     Positive Predictive Value (Precision) (female): 0.8021
#     False Discovery Rate (female): 0.1979
#     False Omission Rate (female): 0.3448
#     Negative Predictive Value (female): 0.6552
#     True Positive Rate (male): 0.7353
#     False Positive Rate (male): 0.2195
#     False Negative Rate (male): 0.2647
#     True Negative Rate (male): 0.7805
#     Positive Predictive Value (Precision) (male): 0.7353
#     False Discovery Rate (male): 0.2647
#     False Omission Rate (male): 0.2195
#     Negative Predictive Value (male): 0.7805
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %% [markdown]
# # Results with Custom Algorithm

# %%
from sklearn.preprocessing import LabelEncoder
df = imdb_custom_debiased
feature_columns = [col for col in df.columns if col.startswith('sentence_embedding_')]
target_column = 'sentiment'
protected_column = 'gender'
test_size = 0.2
random_state = 42

# Instantiate the ClassifierComparison object
cc = ClassifierComparison(df, feature_columns, target_column, protected_column, test_size, random_state)

# Encode the sentiment column to numeric values
label_encoder = LabelEncoder()
df['sentiment'] = label_encoder.fit_transform(df['sentiment'])
print("Unique values in 'sentiment' after encoding:", df['sentiment'].unique())
cc = ClassifierComparison(df, feature_columns, target_column, protected_column, test_size, random_state)

# Train and evaluate classifiers
cc.train_and_evaluate()

# Display results
cc.display_results()
# Out:
# Unique values in 'sentiment' after encoding: [1 0]
# Logistic Regression: Accuracy - 0.6050, Demographic Parity Difference - 0.0267, Equalized Odds Difference - 0.0294
#     True Positive Rate: 0.9917
#     False Positive Rate: 0.9873
#     False Negative Rate: 0.0083
#     True Negative Rate: 0.0127
#     Positive Predictive Value (Precision): 0.6061
#     False Discovery Rate: 0.3939
#     False Omission Rate: 0.5000
#     Negative Predictive Value: 0.5000
#     True Positive Rate (female): 1.0000
#     False Positive Rate (female): 1.0000
#     False Negative Rate (female): 0.0000
#     True Negative Rate (female): 0.0000
#     Positive Predictive Value (Precision) (female): 0.6960
#     False Discovery Rate (female): 0.3040
#     False Omission Rate (female): 0.0000
#     Negative Predictive Value (female): 0.0000
#     True Positive Rate (male): 0.9706
#     False Positive Rate (male): 0.9756
#     False Negative Rate (male): 0.0294
#     True Negative Rate (male): 0.0244
#     Positive Predictive Value (Precision) (male): 0.4521
#     False Discovery Rate (male): 0.5479
#     False Omission Rate (male): 0.5000
#     Negative Predictive Value (male): 0.5000
#
# Decision Tree: Accuracy - 0.5850, Demographic Parity Difference - 0.0960, Equalized Odds Difference - 0.0669
#     True Positive Rate: 0.6364
#     False Positive Rate: 0.4937
#     False Negative Rate: 0.3636
#     True Negative Rate: 0.5063
#     Positive Predictive Value (Precision): 0.6638
#     False Discovery Rate: 0.3362
#     False Omission Rate: 0.5238
#     Negative Predictive Value: 0.4762
#     True Positive Rate (female): 0.6552
#     False Positive Rate (female): 0.5263
#     False Negative Rate (female): 0.3448
#     True Negative Rate (female): 0.4737
#     Positive Predictive Value (Precision) (female): 0.7403
#     False Discovery Rate (female): 0.2597
#     False Omission Rate (female): 0.6250
#     Negative Predictive Value (female): 0.3750
#     True Positive Rate (male): 0.5882
#     False Positive Rate (male): 0.4634
#     False Negative Rate (male): 0.4118
#     True Negative Rate (male): 0.5366
#     Positive Predictive Value (Precision) (male): 0.5128
#     False Discovery Rate (male): 0.4872
#     False Omission Rate (male): 0.3889
#     Negative Predictive Value (male): 0.6111
#
# Random Forest: Accuracy - 0.7250, Demographic Parity Difference - 0.3307, Equalized Odds Difference - 0.3145
#     True Positive Rate: 0.8512
#     False Positive Rate: 0.4684
#     False Negative Rate: 0.1488
#     True Negative Rate: 0.5316
#     Positive Predictive Value (Precision): 0.7357
#     False Discovery Rate: 0.2643
#     False Omission Rate: 0.3000
#     Negative Predictive Value: 0.7000
#     True Positive Rate (female): 0.9080
#     False Positive Rate (female): 0.6316
#     False Negative Rate (female): 0.0920
#     True Negative Rate (female): 0.3684
#     Positive Predictive Value (Precision) (female): 0.7670
#     False Discovery Rate (female): 0.2330
#     False Omission Rate (female): 0.3636
#     Negative Predictive Value (female): 0.6364
#     True Positive Rate (male): 0.7059
#     False Positive Rate (male): 0.3171
#     False Negative Rate (male): 0.2941
#     True Negative Rate (male): 0.6829
#     Positive Predictive Value (Precision) (male): 0.6486
#     False Discovery Rate (male): 0.3514
#     False Omission Rate (male): 0.2632
#     Negative Predictive Value (male): 0.7368
#
# Support Vector Machine: Accuracy - 0.7450, Demographic Parity Difference - 0.3147, Equalized Odds Difference - 0.3370
#     True Positive Rate: 0.8595
#     False Positive Rate: 0.4304
#     False Negative Rate: 0.1405
#     True Negative Rate: 0.5696
#     Positive Predictive Value (Precision): 0.7536
#     False Discovery Rate: 0.2464
#     False Omission Rate: 0.2742
#     Negative Predictive Value: 0.7258
#     True Positive Rate (female): 0.8966
#     False Positive Rate (female): 0.6053
#     False Negative Rate (female): 0.1034
#     True Negative Rate (female): 0.3947
#     Positive Predictive Value (Precision) (female): 0.7723
#     False Discovery Rate (female): 0.2277
#     False Omission Rate (female): 0.3750
#     Negative Predictive Value (female): 0.6250
#     True Positive Rate (male): 0.7647
#     False Positive Rate (male): 0.2683
#     False Negative Rate (male): 0.2353
#     True Negative Rate (male): 0.7317
#     Positive Predictive Value (Precision) (male): 0.7027
#     False Discovery Rate (male): 0.2973
#     False Omission Rate (male): 0.2105
#     Negative Predictive Value (male): 0.7895
#
# K-Nearest Neighbors: Accuracy - 0.6800, Demographic Parity Difference - 0.3707, Equalized Odds Difference - 0.4403
#     True Positive Rate: 0.7686
#     False Positive Rate: 0.4557
#     False Negative Rate: 0.2314
#     True Negative Rate: 0.5443
#     Positive Predictive Value (Precision): 0.7209
#     False Discovery Rate: 0.2791
#     False Omission Rate: 0.3944
#     Negative Predictive Value: 0.6056
#     True Positive Rate (female): 0.8276
#     False Positive Rate (female): 0.6842
#     False Negative Rate (female): 0.1724
#     True Negative Rate (female): 0.3158
#     Positive Predictive Value (Precision) (female): 0.7347
#     False Discovery Rate (female): 0.2653
#     False Omission Rate (female): 0.5556
#     Negative Predictive Value (female): 0.4444
#     True Positive Rate (male): 0.6176
#     False Positive Rate (male): 0.2439
#     False Negative Rate (male): 0.3824
#     True Negative Rate (male): 0.7561
#     Positive Predictive Value (Precision) (male): 0.6774
#     False Discovery Rate (male): 0.3226
#     False Omission Rate (male): 0.2955
#     Negative Predictive Value (male): 0.7045
#
# Extra Trees: Accuracy - 0.7400, Demographic Parity Difference - 0.3013, Equalized Odds Difference - 0.2619
#     True Positive Rate: 0.8595
#     False Positive Rate: 0.4430
#     False Negative Rate: 0.1405
#     True Negative Rate: 0.5570
#     Positive Predictive Value (Precision): 0.7482
#     False Discovery Rate: 0.2518
#     False Omission Rate: 0.2787
#     Negative Predictive Value: 0.7213
#     True Positive Rate (female): 0.9080
#     False Positive Rate (female): 0.5789
#     False Negative Rate (female): 0.0920
#     True Negative Rate (female): 0.4211
#     Positive Predictive Value (Precision) (female): 0.7822
#     False Discovery Rate (female): 0.2178
#     False Omission Rate (female): 0.3333
#     Negative Predictive Value (female): 0.6667
#     True Positive Rate (male): 0.7353
#     False Positive Rate (male): 0.3171
#     False Negative Rate (male): 0.2647
#     True Negative Rate (male): 0.6829
#     Positive Predictive Value (Precision) (male): 0.6579
#     False Discovery Rate (male): 0.3421
#     False Omission Rate (male): 0.2432
#     Negative Predictive Value (male): 0.7568
#
# Gradient Boosting: Accuracy - 0.7400, Demographic Parity Difference - 0.3440, Equalized Odds Difference - 0.3594
#     True Positive Rate: 0.8264
#     False Positive Rate: 0.3924
#     False Negative Rate: 0.1736
#     True Negative Rate: 0.6076
#     Positive Predictive Value (Precision): 0.7634
#     False Discovery Rate: 0.2366
#     False Omission Rate: 0.3043
#     Negative Predictive Value: 0.6957
#     True Positive Rate (female): 0.8736
#     False Positive Rate (female): 0.5789
#     False Negative Rate (female): 0.1264
#     True Negative Rate (female): 0.4211
#     Positive Predictive Value (Precision) (female): 0.7755
#     False Discovery Rate (female): 0.2245
#     False Omission Rate (female): 0.4074
#     Negative Predictive Value (female): 0.5926
#     True Positive Rate (male): 0.7059
#     False Positive Rate (male): 0.2195
#     False Negative Rate (male): 0.2941
#     True Negative Rate (male): 0.7805
#     Positive Predictive Value (Precision) (male): 0.7273
#     False Discovery Rate (male): 0.2727
#     False Omission Rate (male): 0.2381
#     Negative Predictive Value (male): 0.7619
#
# AdaBoost: Accuracy - 0.7600, Demographic Parity Difference - 0.2373, Equalized Odds Difference - 0.2054
#     True Positive Rate: 0.8430
#     False Positive Rate: 0.3671
#     False Negative Rate: 0.1570
#     True Negative Rate: 0.6329
#     Positive Predictive Value (Precision): 0.7786
#     False Discovery Rate: 0.2214
#     False Omission Rate: 0.2754
#     Negative Predictive Value: 0.7246
#     True Positive Rate (female): 0.8621
#     False Positive Rate (female): 0.4737
#     False Negative Rate (female): 0.1379
#     True Negative Rate (female): 0.5263
#     Positive Predictive Value (Precision) (female): 0.8065
#     False Discovery Rate (female): 0.1935
#     False Omission Rate (female): 0.3750
#     Negative Predictive Value (female): 0.6250
#     True Positive Rate (male): 0.7941
#     False Positive Rate (male): 0.2683
#     False Negative Rate (male): 0.2059
#     True Negative Rate (male): 0.7317
#     Positive Predictive Value (Precision) (male): 0.7105
#     False Discovery Rate (male): 0.2895
#     False Omission Rate (male): 0.1892
#     Negative Predictive Value (male): 0.8108
#
# Linear SVC: Accuracy - 0.7550, Demographic Parity Difference - 0.2987, Equalized Odds Difference - 0.3389
#     True Positive Rate: 0.8926
#     False Positive Rate: 0.4557
#     False Negative Rate: 0.1074
#     True Negative Rate: 0.5443
#     Positive Predictive Value (Precision): 0.7500
#     False Discovery Rate: 0.2500
#     False Omission Rate: 0.2321
#     Negative Predictive Value: 0.7679
#     True Positive Rate (female): 0.9195
#     False Positive Rate (female): 0.6316
#     False Negative Rate (female): 0.0805
#     True Negative Rate (female): 0.3684
#     Positive Predictive Value (Precision) (female): 0.7692
#     False Discovery Rate (female): 0.2308
#     False Omission Rate (female): 0.3333
#     Negative Predictive Value (female): 0.6667
#     True Positive Rate (male): 0.8235
#     False Positive Rate (male): 0.2927
#     False Negative Rate (male): 0.1765
#     True Negative Rate (male): 0.7073
#     Positive Predictive Value (Precision) (male): 0.7000
#     False Discovery Rate (male): 0.3000
#     False Omission Rate (male): 0.1714
#     Negative Predictive Value (male): 0.8286
#
# Gaussian Mixture: Accuracy - 0.3950, Demographic Parity Difference - 0.0000, Equalized Odds Difference - 0.0000
#     True Positive Rate: 0.0000
#     False Positive Rate: 0.0000
#     False Negative Rate: 1.0000
#     True Negative Rate: 1.0000
#     Positive Predictive Value (Precision): 0.0000
#     False Discovery Rate: 0.0000
#     False Omission Rate: 0.6050
#     Negative Predictive Value: 0.3950
#     True Positive Rate (female): 0.0000
#     False Positive Rate (female): 0.0000
#     False Negative Rate (female): 1.0000
#     True Negative Rate (female): 1.0000
#     Positive Predictive Value (Precision) (female): 0.0000
#     False Discovery Rate (female): 0.0000
#     False Omission Rate (female): 0.6960
#     Negative Predictive Value (female): 0.3040
#     True Positive Rate (male): 0.0000
#     False Positive Rate (male): 0.0000
#     False Negative Rate (male): 1.0000
#     True Negative Rate (male): 1.0000
#     Positive Predictive Value (Precision) (male): 0.0000
#     False Discovery Rate (male): 0.0000
#     False Omission Rate (male): 0.4533
#     Negative Predictive Value (male): 0.5467
#
# Linear Discriminant Analysis: Accuracy - 0.7450, Demographic Parity Difference - 0.1067, Equalized Odds Difference - 0.0125
#     True Positive Rate: 0.7851
#     False Positive Rate: 0.3165
#     False Negative Rate: 0.2149
#     True Negative Rate: 0.6835
#     Positive Predictive Value (Precision): 0.7917
#     False Discovery Rate: 0.2083
#     False Omission Rate: 0.3250
#     Negative Predictive Value: 0.6750
#     True Positive Rate (female): 0.7816
#     False Positive Rate (female): 0.3158
#     False Negative Rate (female): 0.2184
#     True Negative Rate (female): 0.6842
#     Positive Predictive Value (Precision) (female): 0.8500
#     False Discovery Rate (female): 0.1500
#     False Omission Rate (female): 0.4222
#     Negative Predictive Value (female): 0.5778
#     True Positive Rate (male): 0.7941
#     False Positive Rate (male): 0.3171
#     False Negative Rate (male): 0.2059
#     True Negative Rate (male): 0.6829
#     Positive Predictive Value (Precision) (male): 0.6750
#     False Discovery Rate (male): 0.3250
#     False Omission Rate (male): 0.2000
#     Negative Predictive Value (male): 0.8000
#
# MLP Classifier: Accuracy - 0.7400, Demographic Parity Difference - 0.3173, Equalized Odds Difference - 0.3350
#     True Positive Rate: 0.8347
#     False Positive Rate: 0.4051
#     False Negative Rate: 0.1653
#     True Negative Rate: 0.5949
#     Positive Predictive Value (Precision): 0.7594
#     False Discovery Rate: 0.2406
#     False Omission Rate: 0.2985
#     Negative Predictive Value: 0.7015
#     True Positive Rate (female): 0.8736
#     False Positive Rate (female): 0.5789
#     False Negative Rate (female): 0.1264
#     True Negative Rate (female): 0.4211
#     Positive Predictive Value (Precision) (female): 0.7755
#     False Discovery Rate (female): 0.2245
#     False Omission Rate (female): 0.4074
#     Negative Predictive Value (female): 0.5926
#     True Positive Rate (male): 0.7353
#     False Positive Rate (male): 0.2439
#     False Negative Rate (male): 0.2647
#     True Negative Rate (male): 0.7561
#     Positive Predictive Value (Precision) (male): 0.7143
#     False Discovery Rate (male): 0.2857
#     False Omission Rate (male): 0.2250
#     Negative Predictive Value (male): 0.7750
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %% [markdown]
# # Additional Code for Future Investigation

# %%
 # Using Pre-trained Word Embeddings with a Feedforward Neural Network
import numpy as np
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Embedding, GlobalAveragePooling1D
from keras.initializers import Constant

# Load GloVe embeddings
embeddings_index = {}
with open('glove.6B.100d.txt') as f:
    for line in f:
        word, coefs = line.split(maxsplit=1)
        coefs = np.fromstring(coefs, 'f', sep=' ')
        embeddings_index[word] = coefs

# Prepare the tokenizer and the embedding matrix
tokenizer = Tokenizer()
tokenizer.fit_on_texts(texts)
sequences = tokenizer.texts_to_sequences(texts)
word_index = tokenizer.word_index

num_words = len(word_index) + 1
embedding_dim = 100
embedding_matrix = np.zeros((num_words, embedding_dim))
for word, i in word_index.items():
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        embedding_matrix[i] = embedding_vector

# Define model
model = Sequential()
model.add(Embedding(num_words,
                    embedding_dim,
                    embeddings_initializer=Constant(embedding_matrix),
                    input_length=max_length,
                    trainable=False))
model.add(GlobalAveragePooling1D())
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train
model.fit(X_train, y_train, epochs=10, validation_data=(X_test, y_test))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-43-a450d42bfa85> in <cell line: 11>()
#       9 # Load GloVe embeddings
#      10 embeddings_index = {}
# ---> 11 with open('glove.6B.100d.txt') as f:
#      12    for line in f:
#      13        word, coefs = line.split(maxsplit=1)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'glove.6B.100d.txt'

# %%
import pandas as pd
from collections import Counter

# Sample DataFrame
data = {
    'text': ["The quick brown fox.", "The lazy dog jumps.", "The quick brown fox.", "The lazy dog jumps."],
    'label': [0, 1, 0, 1]
}
df = pd.DataFrame(data)

def adjust_class_proportion(df):
    # Count the occurrences of each class label
    class_counts = Counter(df['label'])

    # Find the minimum class count
    min_count = min(class_counts.values())

    # Create an empty DataFrame to store adjusted samples
    adjusted_df = pd.DataFrame(columns=df.columns)

    # Iterate over each class label
    for label, count in class_counts.items():
        # Sample the dataframe to have the same number of samples as the minimum class count
        class_df = df[df['label'] == label].sample(min_count, replace=False)

        # Append the sampled dataframe to the adjusted_df
        adjusted_df = pd.concat([adjusted_df, class_df], ignore_index=True)

    return adjusted_df

# Adjust the class proportion
adjusted_df = adjust_class_proportion(df)

print("Original DataFrame:")
print(df)
print("\nAdjusted DataFrame:")
print(adjusted_df)
# Out:
# Original DataFrame:
#                    text  label
# 0  The quick brown fox.      0
# 1   The lazy dog jumps.      1
# 2  The quick brown fox.      0
# 3   The lazy dog jumps.      1
#
# Adjusted DataFrame:
#                    text label
# 0  The quick brown fox.     0
# 1  The quick brown fox.     0
# 2   The lazy dog jumps.     1
# 3   The lazy dog jumps.     1

# %% [markdown]
# # Downstream Debiasing Implementation

# %%
# Version 1
import numpy as np
import pandas as pd
from sklearn.metrics import accuracy_score, f1_score
from transformers import BertTokenizer, BertForSequenceClassification, Trainer, TrainingArguments
from datasets import load_dataset
from fairlearn.metrics import MetricFrame, selection_rate, equalized_odds_difference

# Function to measure biases in sentiment predictions
def bias_metrics(y_true, y_pred, sensitive_features):
    mf = MetricFrame(metrics={
        'accuracy': accuracy_score,
        'selection_rate': selection_rate,
        'equalized_odds_difference': lambda y_true, y_pred: equalized_odds_difference(y_true, y_pred, sensitive_feature=sensitive_features)
    },
    y_true=y_true,
    y_pred=y_pred,
    sensitive_features=sensitive_features)
    return mf.by_group

# Load the IMDB dataset
dataset = load_dataset("imdb")

# Assume sensitive attribute 'gender' is available in the dataset
sensitive_features = dataset['train']['gender']

# Tokenization using BERT
tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")

def tokenize_function(examples):
    return tokenizer(examples['text'], padding="max_length", truncation=True)

tokenized_datasets = dataset.map(tokenize_function, batched=True)

# Split the data into train and test
train_dataset, test_dataset = tokenized_datasets["train"], tokenized_datasets["test"]

# Load BERT for sequence classification
model = BertForSequenceClassification.from_pretrained("bert-base-uncased")

# Training arguments
training_args = TrainingArguments(
    output_dir="./results",
    evaluation_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    num_train_epochs=3,
    weight_decay=0.01,
)

# Initialize Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=test_dataset
)

# Train the model
trainer.train()


# Evaluate the model using bias metrics
predictions = trainer.predict(test_dataset)
preds = np.argmax(predictions.predictions, axis=-1)
bias_results = bias_metrics(predictions.label_ids, preds, sensitive_features)


print(bias_results)

# Calculate accuracy and F1 score
accuracy = accuracy_score(predictions.label_ids, preds)
f1 = f1_score(predictions.label_ids, preds)

print(f"Accuracy: {accuracy}")
print(f"F1 Score: {f1}")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Downloading readme:   0%|          | 0.00/7.81k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/21.0M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/20.5M [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-fe663894c65f> in <cell line: 22>()
#      20
#      21 # Load the IMDB dataset
# ---> 22 dataset = load_dataset("imdb")
#      23
#      24 # Assume sensitive attribute 'gender' is available in the dataset
#
# /usr/local/lib/python3.10/dist-packages/datasets/load.py in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, ignore_verifications, keep_in_memory, save_infos, revision, token, use_auth_token, task, streaming, num_proc, storage_options, trust_remote_code, **config_kwargs)
#    2607
#    2608     # Download and prepare data
# -> 2609     builder_instance.download_and_prepare(
#    2610         download_config=download_config,
#    2611         download_mode=download_mode,
#
# /usr/local/lib/python3.10/dist-packages/datasets/builder.py in download_and_prepare(self, output_dir, download_config, download_mode, verification_mode, ignore_verifications, try_from_hf_gcs, dl_manager, base_path, use_auth_token, file_format, max_shard_size, num_proc, storage_options, **download_and_prepare_kwargs)
#    1025                         if num_proc is not None:
#    1026                             prepare_split_kwargs["num_proc"] = num_proc
# -> 1027                         self._download_and_prepare(
#    1028                             dl_manager=dl_manager,
#    1029                             verification_mode=verification_mode,
#
# /usr/local/lib/python3.10/dist-packages/datasets/builder.py in _download_and_prepare(self, dl_manager, verification_mode, **prepare_split_kwargs)
#    1098         split_dict = SplitDict(dataset_name=self.dataset_name)
#    1099         split_generators_kwargs = self._make_split_generators_kwargs(prepare_split_kwargs)
# -> 1100         split_generators = self._split_generators(dl_manager, **split_generators_kwargs)
#    1101
#    1102         # Checksums verification
#
# /usr/local/lib/python3.10/dist-packages/datasets/packaged_modules/parquet/parquet.py in _split_generators(self, dl_manager)
#      42             raise ValueError(f"At least one data file must be specified, but got data_files={self.config.data_files}")
#      43         dl_manager.download_config.extract_on_the_fly = True
# ---> 44         data_files = dl_manager.download_and_extract(self.config.data_files)
#      45         if isinstance(data_files, (str, list, tuple)):
#      46             files = data_files
#
# /usr/local/lib/python3.10/dist-packages/datasets/download/download_manager.py in download_and_extract(self, url_or_urls)
#     432             extracted_path(s): `str`, extracted paths of given URL(s).
#     433         """
# --> 434         return self.extract(self.download(url_or_urls))
#     435
#     436     def get_recorded_sizes_checksums(self):
#
# /usr/local/lib/python3.10/dist-packages/datasets/download/download_manager.py in download(self, url_or_urls)
#     255         start_time = datetime.now()
#     256         with stack_multiprocessing_download_progress_bars():
# --> 257             downloaded_path_or_paths = map_nested(
#     258                 download_func,
#     259                 url_or_urls,
#
# /usr/local/lib/python3.10/dist-packages/datasets/utils/py_utils.py in map_nested(function, data_struct, dict_only, map_list, map_tuple, map_numpy, num_proc, parallel_min_length, batched, batch_size, types, disable_tqdm, desc)
#     506                 batch_size = max(len(iterable) // num_proc + int(len(iterable) % num_proc > 0), 1)
#     507             iterable = list(iter_batched(iterable, batch_size))
# --> 508         mapped = [
#     509             _single_map_nested((function, obj, batched, batch_size, types, None, True, None))
#     510             for obj in hf_tqdm(iterable, disable=disable_tqdm, desc=desc)
#
# /usr/local/lib/python3.10/dist-packages/datasets/utils/py_utils.py in <listcomp>(.0)
#     507             iterable = list(iter_batched(iterable, batch_size))
#     508         mapped = [
# --> 509             _single_map_nested((function, obj, batched, batch_size, types, None, True, None))
#     510             for obj in hf_tqdm(iterable, disable=disable_tqdm, desc=desc)
#     511         ]
#
# /usr/local/lib/python3.10/dist-packages/datasets/utils/py_utils.py in _single_map_nested(args)
#     394             }
#     395         else:
# --> 396             mapped = [_single_map_nested((function, v, batched, batch_size, types, None, True, None)) for v in pbar]
#     397             if isinstance(data_struct, list):
#     398                 return mapped
#
# /usr/local/lib/python3.10/dist-packages/datasets/utils/py_utils.py in <listcomp>(.0)
#     394             }
#     395         else:
# --> 396             mapped = [_single_map_nested((function, v, batched, batch_size, types, None, True, None)) for v in pbar]
#     397             if isinstance(data_struct, list):
#     398                 return mapped
#
# /usr/local/lib/python3.10/dist-packages/datasets/utils/py_utils.py in _single_map_nested(args)
#     375         and all(not isinstance(v, types) for v in data_struct)
#     376     ):
# --> 377         return [mapped_item for batch in iter_batched(data_struct, batch_size) for mapped_item in function(batch)]
#     378
#     379     # Reduce logging to keep things readable in multiprocessing with tqdm
#
# /usr/local/lib/python3.10/dist-packages/datasets/utils/py_utils.py in <listcomp>(.0)
#     375         and all(not isinstance(v, types) for v in data_struct)
#     376     ):
# --> 377         return [mapped_item for batch in iter_batched(data_struct, batch_size) for mapped_item in function(batch)]
#     378
#     379     # Reduce logging to keep things readable in multiprocessing with tqdm
#
# /usr/local/lib/python3.10/dist-packages/datasets/download/download_manager.py in _download_batched(self, url_or_filenames, download_config)
#     311             )
#     312         else:
# --> 313             return [
#     314                 self._download_single(url_or_filename, download_config=download_config)
#     315                 for url_or_filename in url_or_filenames
#
# /usr/local/lib/python3.10/dist-packages/datasets/download/download_manager.py in <listcomp>(.0)
#     312         else:
#     313             return [
# --> 314                 self._download_single(url_or_filename, download_config=download_config)
#     315                 for url_or_filename in url_or_filenames
#     316             ]
#
# /usr/local/lib/python3.10/dist-packages/datasets/download/download_manager.py in _download_single(self, url_or_filename, download_config)
#     321             # append the relative path to the base_path
#     322             url_or_filename = url_or_path_join(self._base_path, url_or_filename)
# --> 323         out = cached_path(url_or_filename, download_config=download_config)
#     324         out = tracked_str(out)
#     325         out.set_origin(url_or_filename)
#
# /usr/local/lib/python3.10/dist-packages/datasets/utils/file_utils.py in cached_path(url_or_filename, download_config, **download_kwargs)
#     199     if is_remote_url(url_or_filename):
#     200         # URL, so get it from the cache (downloading if necessary)
# --> 201         output_path = get_from_cache(
#     202             url_or_filename,
#     203             cache_dir=cache_dir,
#
# /usr/local/lib/python3.10/dist-packages/datasets/utils/file_utils.py in get_from_cache(url, cache_dir, force_download, proxies, etag_timeout, resume_download, user_agent, local_files_only, use_etag, max_retries, token, use_auth_token, ignore_url_params, storage_options, download_desc, disable_tqdm)
#     674                 ftp_get(url, temp_file)
#     675             elif scheme not in ("http", "https"):
# --> 676                 fsspec_get(
#     677                     url, temp_file, storage_options=storage_options, desc=download_desc, disable_tqdm=disable_tqdm
#     678                 )
#
# /usr/local/lib/python3.10/dist-packages/datasets/utils/file_utils.py in fsspec_get(url, temp_file, storage_options, desc, disable_tqdm)
#     383         }
#     384     )
# --> 385     fs.get_file(path, temp_file.name, callback=callback)
#     386
#     387
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/hf_file_system.py in get_file(self, rpath, lpath, callback, outfile, **kwargs)
#     632         callback.set_size(expected_size)
#     633         try:
# --> 634             http_get(
#     635                 url=hf_hub_url(
#     636                     repo_id=resolve_remote_path.repo_id,
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py in http_get(url, temp_file, proxies, resume_size, headers, expected_size, displayed_filename, _nb_retries, _tqdm_bar)
#     454         headers["Range"] = "bytes=%d-" % (resume_size,)
#     455
# --> 456     r = _request_wrapper(
#     457         method="GET", url=url, stream=True, proxies=proxies, headers=headers, timeout=HF_HUB_DOWNLOAD_TIMEOUT
#     458     )
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py in _request_wrapper(method, url, follow_relative_redirects, **params)
#     390
#     391     # Perform request and return if status_code is not in the retry list.
# --> 392     response = get_session().request(method=method, url=url, **params)
#     393     hf_raise_for_status(response)
#     394     return response
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587         }
#     588         send_kwargs.update(settings)
# --> 589         resp = self.send(prep, **send_kwargs)
#     590
#     591         return resp
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     723             # Redirect resolving generator.
#     724             gen = self.resolve_redirects(r, request, **kwargs)
# --> 725             history = [resp for resp in gen]
#     726         else:
#     727             history = []
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in <listcomp>(.0)
#     723             # Redirect resolving generator.
#     724             gen = self.resolve_redirects(r, request, **kwargs)
# --> 725             history = [resp for resp in gen]
#     726         else:
#     727             history = []
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in resolve_redirects(self, resp, req, stream, timeout, verify, cert, proxies, yield_requests, **adapter_kwargs)
#     264             else:
#     265
# --> 266                 resp = self.send(
#     267                     req,
#     268                     stream=stream,
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     701
#     702         # Send the request
# --> 703         r = adapter.send(request, **kwargs)
#     704
#     705         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_http.py in send(self, request, *args, **kwargs)
#      66         """Catch any RequestException to append request id to the error message for debugging."""
#      67         try:
# ---> 68             return super().send(request, *args, **kwargs)
#      69         except requests.RequestException as e:
#      70             request_id = request.headers.get(X_AMZN_TRACE_ID)
#
# /usr/local/lib/python3.10/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     484
#     485         try:
# --> 486             resp = conn.urlopen(
#     487                 method=request.method,
#     488                 url=url,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     789
#     790             # Make the request on the HTTPConnection object
# --> 791             response = self._make_request(
#     792                 conn,
#     793                 method,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535         # Receive the response from the server
#     536         try:
# --> 537             response = conn.getresponse()
#     538         except (BaseSSLError, OSError) as e:
#     539             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connection.py in getresponse(self)
#     459
#     460         # Get the response from http.client.HTTPConnection
# --> 461         httplib_response = super().getresponse()
#     462
#     463         try:
#
# /usr/lib/python3.10/http/client.py in getresponse(self)
#    1373         try:
#    1374             try:
# -> 1375                 response.begin()
#    1376             except ConnectionError:
#    1377                 self.close()
#
# /usr/lib/python3.10/http/client.py in begin(self)
#     316         # read until we get a non-100 response
#     317         while True:
# --> 318             version, status, reason = self._read_status()
#     319             if status != CONTINUE:
#     320                 break
#
# /usr/lib/python3.10/http/client.py in _read_status(self)
#     277
#     278     def _read_status(self):
# --> 279         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280         if len(line) > _MAXLINE:
#     281             raise LineTooLong("status line")
#
# /usr/lib/python3.10/socket.py in readinto(self, b)
#     703         while True:
#     704             try:
# --> 705                 return self._sock.recv_into(b)
#     706             except timeout:
#     707                 self._timeout_occurred = True
#
# /usr/lib/python3.10/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1301                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1302                   self.__class__)
# -> 1303             return self.read(nbytes, buffer)
#    1304         else:
#    1305             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.10/ssl.py in read(self, len, buffer)
#    1157         try:
#    1158             if buffer is not None:
# -> 1159                 return self._sslobj.read(len, buffer)
#    1160             else:
#    1161                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# Version 9001
import numpy as np
from transformers import BertTokenizer, BertForSequenceClassification, Trainer, TrainingArguments
from datasets import load_dataset
from sklearn.metrics import accuracy_score, f1_score
from fairlearn.metrics import MetricFrame, selection_rate, equalized_odds_difference

# Function to measure biases in sentiment predictions
def bias_metrics(y_true, y_pred, sensitive_features):
    mf = MetricFrame(metrics={
        'accuracy': accuracy_score,
        'selection_rate': selection_rate,
        'equalized_odds_difference': lambda y_true, y_pred: equalized_odds_difference(y_true, y_pred, sensitive_feature=sensitive_features)
    },
    y_true=y_true,
    y_pred=y_pred,
    sensitive_features=sensitive_features)
    return mf.by_group

# Load the IMDB dataset
dataset = load_dataset("imdb")

# Tokenization using BERT
tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")

def tokenize_function(examples):
    return tokenizer(examples['text'], padding="max_length", truncation=True)

tokenized_datasets = dataset.map(tokenize_function, batched=True)

# Assuming a function to debias embeddings (pseudocode) - MUST IMPLEMENT
def debias_embeddings(model):
    # Pseudocode: Modify model embeddings based on debiasing algorithm
    pass

# Define model loading function to allow switching between original and debiased
def load_model(debias=False):
    model = BertForSequenceClassification.from_pretrained("bert-base-uncased")
    if debias:
        debias_embeddings(model)
    return model

# Load models
original_model = load_model(debias=False)
debiased_model = load_model(debias=True)

# Training arguments
training_args = TrainingArguments(
    output_dir="./results",
    evaluation_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    num_train_epochs=3,
    weight_decay=0.01,
)

# Initialize Trainers for both models
trainer_original = Trainer(
    model=original_model,
    args=training_args,
    train_dataset=tokenized_datasets["train"],
    eval_dataset=tokenized_datasets["test"]
)

trainer_debiased = Trainer(
    model=debiased_model,
    args=training_args,
    train_dataset=tokenized_datasets["train"],
    eval_dataset=tokenized_datasets["test"]
)

# Train both models
trainer_original.train()
trainer_debiased.train()

# Evaluate both models using bias metrics
predictions_original = trainer_original.predict(tokenized_datasets["test"])
predictions_debiased = trainer_debiased.predict(tokenized_datasets["test"])

preds_original = np.argmax(predictions_original.predictions, axis=-1)
preds_debiased = np.argmax(predictions_debiased.predictions, axis=-1)

# Assume sensitive attribute 'gender' is available in the dataset
sensitive_features = dataset['test']['gender']

bias_results_original = bias_metrics(predictions_original.label_ids, preds_original, sensitive_features)
bias_results_debiased = bias_metrics(predictions_debiased.label_ids, preds_debiased, sensitive_features)

print("Original Model Bias and Accuracy:")
print(bias_results_original)

print("Debiased Model Bias and Accuracy:")
print(bias_results_debiased)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='210' max='9375' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 210/9375 3:16:47 < 144:31:23, 0.02 it/s, Epoch 0.07/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
